# %%
import matplotlib.pyplot as plt
from random import randint
a = []
y = []
for i in range(100):
    a.append(i)

for i in range(100):
    y.append(randint(100, 1000))

# plt.ylim((100, 250))
plt.xlim((10, 50))
plt.plot(a, y)
plt.show()
