# %%
class Sorting():
    def __init__(self) -> None:
        pass
    def bubble_sort(self, array):

        for i in range(len(array)):

            swapped = False
            
            for j in range(len(array) - i - 1, len(array) - 1):
                print(array)
                if array[j] > array[j + 1]:
                    array[j], array[j + 1] = array[j + 1], array[j]
                    swapped = True

                if not swapped:
                    break
        
        return array
    
    def bubble_sort_version_2(self, array, reverse= False):

        passes = 0
        if not reverse:
            for i in range(len(array) - 1): # for i in range length of list - 1 --> dont need to check the last element

                noSwaps = True
                # Size of problem decreases by 1 every time
                for j in range(len(array) - 1 - i):
                    
                    if array[j] > array[j + 1]:
                        array[j], array[j + 1] = array[j + 1], array[j]
                        noSwaps= False
                    
                passes += 1
                if noSwaps:
                    break
        else:
            for i in range(len(array) - 1): # for i in range length of list - 1 --> dont need to check the last element

                noSwaps= True
                # Size of problem decreases by 1 every time
                for j in range(len(array) - 1 - i):
                    passes += 1
                    if array[j] < array[j + 1]:
                        array[j], array[j + 1] = array[j + 1], array[j]
                        noSwaps = False

                passes += 1
                if noSwaps:
                    break
        
        print(f'Sorted after {passes} passes')
        return array
    
    def bubble_sort_recursive(self, arr, arr_size):

        if arr_size == 1:
            return arr
        
        for i in range(len(arr) - 1):
            if arr[i] > arr[i + 1]:
                arr[i], arr[i + 1] = arr[i + 1], arr[i]

        return self.bubble_sort_recurvise(arr, arr_size - 1)
    
    def merge_sort(self, array):
        if len(array) > 1:
            mid = len(array) // 2

            left_partition = array[:mid]
            right_partition = array[mid:]

            self.merge_sort(left_partition)
            self.merge_sort(right_partition)

            temp1 = temp2 = temp3 = 0

            while len(left_partition) > temp1 and len(right_partition) > temp2:
                if left_partition[temp1] <= right_partition[temp2]:
                    array[temp3] = left_partition[temp1]

                    temp1 += 1
                else:
                    array[temp3] = right_partition[temp2]
                    temp2 += 1

                temp3 += 1

            while temp1 < len(left_partition):
                array[temp3] = left_partition[temp1]
                temp3 += 1
                temp1 += 1
            
            while temp2 < len(right_partition):
                array[temp3] = right_partition[temp2]
                temp3 += 1
                temp2 += 1

        return array
    
    def selection_sort(self, array):
        
        for i in range(len(array)):

            minimum = i

            for j in range(i + 1, len(array)):
                if array[j] < array[minimum]:
                    minimum = j

            array[i], array[minimum] = array[minimum], array[i]

        return array
    
    def quick_sort(self, array):
        pass

    def insertion_sort(self, array):
        for i in range(1, len(array)):

            curr_element = array[i]

            j = i - 1

            while curr_element < array[j] and j + 1 >= 1:
                array[j + 1] = array[j]
                array[j] = curr_element
                j -= 1

        return array
    

sorts = Sorting()
sorts.insertion_sort([5, 4, 6, 5, 4, 5, 8, 9, 2, 1, 7, 5, 10])

# %% [markdown]
# ### Generate a list of 10 random unique integers between 0 and 100
# ### Write a bubble sort function
# ### Sort the list of integers in descending order

# %%
import random

arr = []
while len(arr) <= 10:
    number = random.randint(0, 100)
    if number not in arr:
        arr.append(number)
    else:
        continue

    
def bubble_sort(array):
    swaps = 0
    passes = 0
    for i in range(len(array) - 1): # for i in range length of list - 1 --> dont need to check the last element

        noSwaps= True
        # Size of problem decreases by 1 every time
        for j in range(len(array) - 1 - i):
            if array[j] < array[j + 1]:
                array[j], array[j + 1] = array[j + 1], array[j]
                swaps += 1
                noSwaps= False

        passes += 1
        if noSwaps:
            break

    print(f'Sorted with {passes} passes, and {swaps} swaps')
    return array

sorted_arr = bubble_sort(arr)
print(sorted_arr)
# Out:
# Sorted with 9 passes, and 31 swaps
# [98, 74, 69, 68, 67, 59, 53, 52, 43, 25, 3]
